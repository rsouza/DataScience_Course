# %%
# data source: https://www.epa.gov/compliance-and-fuel-economy-data/data-cars-used-testing-fuel-economy

# %% [markdown]
# # 1. Must-do Exploration
# In this section we will be exploring the data on Cars used for Testing fuel economy (car models are from year 2010).

# %%
# TASK 1 >>>
import pandas as pd
import numpy as np
# Load the dataset 'fuel_economy_data_2010.csv' using pd.read_csv('...', index_col = 0) and store it in a variable called "data"
data = pd.read_csv('./Data/fuel_economy_data_2010.csv', index_col = 0)

# %%
# TASK 2 >>> Display the first five rows of the DataFrame using .head() method
data.head()
# Out:
#    Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 0        2010              aston martin          ASX
# 1        2010              aston martin          ASX
# 2        2010              aston martin          ASX
# 3        2010              aston martin          ASX
# 4        2010              aston martin          ASX
#
#   Represented Test Veh Model Test Vehicle ID  Test Veh Configuration #  \
# 0                        DB9        106CP101                         0
# 1                        DB9        106CP101                         0
# 2                        DB9         KX08PBV                         0
# 3                        DB9         KX08PBV                         0
# 4                        DBS        304M2323                         0
#
#    Test Veh Displacement (L) Actual Tested Testgroup Vehicle Type  \
# 0                        5.9            9ASXV05.9VH1          Car
# 1                        5.9            9ASXV05.9VH1          Car
# 2                        5.9            AASXV05.9VH1          Car
# 3                        5.9            AASXV05.9VH1          Car
# 4                        5.9            9ASXV05.9VH1          Car
#
#    Rated Horsepower  # of Cylinders and Rotors Tested Transmission Type  \
# 0               470                        NaN                   Manual
# 1               470                        NaN                   Manual
# 2               470                       12.0           Semi-Automatic
# 3               470                       12.0           Semi-Automatic
# 4               510                        NaN           Semi-Automatic
#
#   Drive System Description  # of Gears Test Fuel Type Description  CO2 (g/mi)
# 0      2-Wheel Drive, Rear           6       Tier 2 Cert Gasoline     649.270
# 1      2-Wheel Drive, Rear           6       Tier 2 Cert Gasoline     378.310
# 2      2-Wheel Drive, Rear           6       Tier 2 Cert Gasoline     546.445
# 3      2-Wheel Drive, Rear           6       Tier 2 Cert Gasoline     323.980
# 4      2-Wheel Drive, Rear           6       Tier 2 Cert Gasoline     612.598

# %%
# TASK 3 >>> Display the last five rows of the DataFrame using .tail() method
data.tail()
# Out:
#       Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 3272        2010                     Volvo          VVX
# 3273        2010                     Volvo          VVX
# 3274        2010                     Volvo          VVX
# 3275        2010                     Volvo          VVX
# 3276        2010                     Volvo          VVX
#
#      Represented Test Veh Model Test Vehicle ID  Test Veh Configuration #  \
# 3272                   XC90 FWD          200904                         2
# 3273                   XC90 FWD          200904                         2
# 3274                   XC90 FWD          200904                         2
# 3275                XC90 V8 AWD          200713                         2
# 3276                XC90 V8 AWD          200713                         2
#
#       Test Veh Displacement (L) Actual Tested Testgroup Vehicle Type  \
# 3272                      3.192            AVVXJ03.2U2N         Both
# 3273                      3.192            AVVXJ03.2U2N         Both
# 3274                      3.192            AVVXJ03.2U2N         Both
# 3275                      4.414            AVVXJ04.4U2N         Both
# 3276                      4.414            AVVXJ04.4U2N         Both
#
#       Rated Horsepower  # of Cylinders and Rotors Tested Transmission Type  \
# 3272               235                        6.0           Semi-Automatic
# 3273               235                        6.0           Semi-Automatic
# 3274               235                        6.0           Semi-Automatic
# 3275               311                        8.0           Semi-Automatic
# 3276               311                        8.0           Semi-Automatic
#
#      Drive System Description  # of Gears Test Fuel Type Description  \
# 3272     2-Wheel Drive, Front           6     Cold CO Regular (CERT)
# 3273     2-Wheel Drive, Front           6     CARB Phase II Gasoline
# 3274     2-Wheel Drive, Front           6     CARB Phase II Gasoline
# 3275     2-Wheel Drive, Front           6     CARB Phase II Gasoline
# 3276     2-Wheel Drive, Front           6     CARB Phase II Gasoline
#
#       CO2 (g/mi)
# 3272       530.0
# 3273       469.0
# 3274       295.0
# 3275       542.0
# 3276       333.0

# %%
# Display 15 random elements from the dataset using .sample() method (by setting parameter n = 15)
data.sample(n=15)
# Out:
#       Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# 1686        2010                  Maserati          MAX
# 524         2010                       BMW          BMX
# 2871        2010                    Toyota          TYX
# 261         2010                       BMW          BMX
# 1617        2010                       Kia          KMX
# 3253        2010                     Volvo          VVX
# 2276        2010                    Nissan          NSX
# 2205        2010                    Nissan          NSX
# 1258        2010                        GM          GMX
# 1129        2010                        GM          GMX
# 577         2010                       BMW          BMX
# 1894        2010             Mercedes-Benz          MBX
# 265         2010                       BMW          BMX
# 3246        2010                     Volvo          VVX
# 58          2010                      Audi          ADX
#
#                Represented Test Veh Model    Test Vehicle ID  \
# 1686                       QUATTROPORTE S  ZAMJK39A690027157
# 524                          X6 xDrive50i            LZ91535
# 2871                                PRIUS            10-ZW1H
# 261                                  128i            VF06008
# 1617                               SEDONA         VQ0L8U55A2
# 3253                          XC60 T6 AWD             201007
# 2276                          NISSAN GT-R             MNE288
# 2205  NISSAN FRONTIER KING CAB PRO-4X 4X4             SRE339
# 1258                              TC10543         62XECP9062
# 1129                                1ZG69         2418Z42999
# 577                         Mini Cooper S            TT90932
# 1894                              SLK 350      R171E35-Z5002
# 265                                  128i            VF45602
# 3246                             XC60 AWD             200903
# 58                             A3 QUATTRO           93UA-AAQ
#
#       Test Veh Configuration #  Test Veh Displacement (L)  \
# 1686                         1                      4.700
# 524                          0                      4.400
# 2871                         3                      1.798
# 261                          2                      3.000
# 1617                         0                      3.800
# 3253                         1                      2.953
# 2276                         2                      3.800
# 2205                         1                      4.000
# 1258                         3                      6.200
# 1129                         4                      2.400
# 577                          3                      1.600
# 1894                         1                      3.498
# 265                          0                      3.000
# 3246                         0                      2.953
# 58                           0                      1.984
#
#      Actual Tested Testgroup Vehicle Type  Rated Horsepower  \
# 1686            AMAXV04.7LEV          Car               424
# 524             ABMXT04.4E71        Truck               400
# 2871            ATYXV01.8HC3          Car                98
# 261             9BMXJ03.0E89         Both               230
# 1617            AKMXT03.8VW5        Truck               250
# 3253            AVVXJ03.0U2T         Both               281
# 2276            9NSXV03.8GBA          Car               480
# 2205            9NSXT04.0G6B        Truck               261
# 1258            AGMXT06.2375        Truck               403
# 1129            AGMXV02.4033          Car               175
# 577             9BMXV01.6LER          Car               175
# 1894            AMBXV03.5U2A          Car               301
# 265             ABMXV03.051R          Car               230
# 3246            AVVXT03.0U2T        Truck               281
# 58              9ADXV02.03UA          Car               200
#
#       # of Cylinders and Rotors Tested Transmission Type  \
# 1686                        8.0                Automatic
# 524                         8.0                Automatic
# 2871                        4.0    Continuously Variable
# 261                         6.0                   Manual
# 1617                        6.0                Automatic
# 3253                        6.0           Semi-Automatic
# 2276                        NaN           Semi-Automatic
# 2205                        6.0                   Manual
# 1258                        8.0                Automatic
# 1129                        4.0                Automatic
# 577                         4.0                   Manual
# 1894                        6.0                   Manual
# 265                         6.0                   Manual
# 3246                        6.0           Semi-Automatic
# 58                          NaN                Automatic
#
#      Drive System Description  # of Gears  \
# 1686      2-Wheel Drive, Rear           6
# 524           All Wheel Drive           6
# 2871     2-Wheel Drive, Front           1
# 261       2-Wheel Drive, Rear           6
# 1617     2-Wheel Drive, Front           5
# 3253     2-Wheel Drive, Front           6
# 2276            4-Wheel Drive           6
# 2205            4-Wheel Drive           6
# 1258      2-Wheel Drive, Rear           6
# 1129     2-Wheel Drive, Front           4
# 577      2-Wheel Drive, Front           6
# 1894      2-Wheel Drive, Rear           6
# 265       2-Wheel Drive, Rear           6
# 3246     2-Wheel Drive, Front           6
# 58       2-Wheel Drive, Front           6
#
#                        Test Fuel Type Description  CO2 (g/mi)
# 1686                         Tier 2 Cert Gasoline  347.386000
# 524                          Tier 2 Cert Gasoline  353.600000
# 2871                         Tier 2 Cert Gasoline  122.898914
# 261                          Tier 2 Cert Gasoline  355.170000
# 1617                         Tier 2 Cert Gasoline  274.910000
# 3253                       CARB Phase II Gasoline  452.450767
# 2276                         Tier 2 Cert Gasoline  491.000000
# 2205                         Tier 2 Cert Gasoline  465.000000
# 1258  E85 (85% Ethanol 15% EPA Unleaded Gasoline)  550.757000
# 1129                         Tier 2 Cert Gasoline  323.942000
# 577                          Tier 2 Cert Gasoline  193.420000
# 1894                         Tier 2 Cert Gasoline  426.970000
# 265                          Tier 2 Cert Gasoline  389.020000
# 3246                       CARB Phase II Gasoline  509.000000
# 58                           Tier 2 Cert Gasoline  325.000000

# %%
# Display 5 random elements from the column 'Test Veh Displacement (L)' using .sample(n = 5)
data['Test Veh Displacement (L)'].sample(n = 5)
# Out:
# 709     3.800
# 298     3.000
# 1725    2.500
# 1807    3.498
# 364     3.000
# Name: Test Veh Displacement (L), dtype: float64

# %%
# TASK 4 >>> Display the shape of the dataset using attribute .shape
data.shape
# Out:
# (3277, 16)

# %%
# Display the short summary of the dataframe using .info() method by setting argument verbose = False
data.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3277 entries, 0 to 3276
# Columns: 16 entries, Model Year to CO2 (g/mi)
# dtypes: float64(3), int64(4), object(9)
# memory usage: 435.2+ KB

# %%
# TASK 5 >>> Display a basic summary of the DataFrame using .info() method
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3277 entries, 0 to 3276
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Model Year                  3277 non-null   int64
#  1   Vehicle Manufacturer Name   3277 non-null   object
#  2   Veh Mfr Code                3277 non-null   object
#  3   Represented Test Veh Model  3277 non-null   object
#  4   Test Vehicle ID             3277 non-null   object
#  5   Test Veh Configuration #    3277 non-null   int64
#  6   Test Veh Displacement (L)   3277 non-null   float64
#  7   Actual Tested Testgroup     3277 non-null   object
#  8   Vehicle Type                3277 non-null   object
#  9   Rated Horsepower            3277 non-null   int64
#  10  # of Cylinders and Rotors   2430 non-null   float64
#  11  Tested Transmission Type    3277 non-null   object
#  12  Drive System Description    3277 non-null   object
#  13  # of Gears                  3277 non-null   int64
#  14  Test Fuel Type Description  3277 non-null   object
#  15  CO2 (g/mi)                  2988 non-null   float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 435.2+ KB

# %%
# TASK 6 >>> Display columns in the dataframe using .columns attribute
data.columns
# Out:
# Index(['Model Year', 'Vehicle Manufacturer Name', 'Veh Mfr Code',
#        'Represented Test Veh Model', 'Test Vehicle ID',
#        'Test Veh Configuration #', 'Test Veh Displacement (L)',
#        'Actual Tested Testgroup', 'Vehicle Type', 'Rated Horsepower',
#        '# of Cylinders and Rotors', 'Tested Transmission Type',
#        'Drive System Description', '# of Gears', 'Test Fuel Type Description',
#        'CO2 (g/mi)'],
#       dtype='object')

# %%
# TASK 7 >>> Display data types of the variables using .dtypes attribute
data.dtypes
# Out:
# Model Year                      int64
# Vehicle Manufacturer Name      object
# Veh Mfr Code                   object
# Represented Test Veh Model     object
# Test Vehicle ID                object
# Test Veh Configuration #        int64
# Test Veh Displacement (L)     float64
# Actual Tested Testgroup        object
# Vehicle Type                   object
# Rated Horsepower                int64
# # of Cylinders and Rotors     float64
# Tested Transmission Type       object
# Drive System Description       object
# # of Gears                      int64
# Test Fuel Type Description     object
# CO2 (g/mi)                    float64
# dtype: object

# %% [markdown]
# # 2. Exploring columns

# %%
# Display a subset of the dataframe's columns based on the column's data types, using .select_dtypes() method 
# Set parameter include=['float64','int64']
data.select_dtypes(include=['float64', 'int64'])
# Out:
#       Model Year  Test Veh Configuration #  Test Veh Displacement (L)  \
# 0           2010                         0                      5.900
# 1           2010                         0                      5.900
# 2           2010                         0                      5.900
# 3           2010                         0                      5.900
# 4           2010                         0                      5.900
# ...          ...                       ...                        ...
# 3272        2010                         2                      3.192
# 3273        2010                         2                      3.192
# 3274        2010                         2                      3.192
# 3275        2010                         2                      4.414
# 3276        2010                         2                      4.414
#
#       Rated Horsepower  # of Cylinders and Rotors  # of Gears  CO2 (g/mi)
# 0                  470                        NaN           6     649.270
# 1                  470                        NaN           6     378.310
# 2                  470                       12.0           6     546.445
# 3                  470                       12.0           6     323.980
# 4                  510                        NaN           6     612.598
# ...                ...                        ...         ...         ...
# 3272               235                        6.0           6     530.000
# 3273               235                        6.0           6     469.000
# 3274               235                        6.0           6     295.000
# 3275               311                        8.0           6     542.000
# 3276               311                        8.0           6     333.000
#
# [3277 rows x 7 columns]

# %%
# TASK 8 >>> Display descriptive statistics using .describe() method
data.describe()
# Out:
#        Model Year  Test Veh Configuration #  Test Veh Displacement (L)  \
# count      3277.0               3277.000000                3277.000000
# mean       2010.0                  2.098871                   3.472831
# std           0.0                  4.067725                   1.296540
# min        2010.0                  0.000000                   0.001000
# 25%        2010.0                  0.000000                   2.400000
# 50%        2010.0                  1.000000                   3.195000
# 75%        2010.0                  2.000000                   4.300000
# max        2010.0                 50.000000                   8.400000
#
#        Rated Horsepower  # of Cylinders and Rotors   # of Gears   CO2 (g/mi)
# count       3277.000000                2430.000000  3277.000000  2988.000000
# mean         263.988404                   5.951852     5.278303   348.713576
# std          107.505203                   1.733995     1.463453   117.920807
# min           35.000000                   3.000000     1.000000   121.840334
# 25%          175.000000                   4.000000     5.000000   255.000000
# 50%          255.000000                   6.000000     6.000000   332.113787
# 75%          315.000000                   8.000000     6.000000   416.025000
# max         1001.000000                  12.000000     8.000000  1012.000000

# %%
# Display summary statistics of all columns of the dataframe regardless of data type by setting argument include = 'all'
data.describe(include = 'all')
# Out:
#         Model Year Vehicle Manufacturer Name Veh Mfr Code  \
# count       3277.0                      3277         3277
# unique         NaN                        33           33
# top            NaN                    Nissan          NSX
# freq           NaN                       485          485
# mean        2010.0                       NaN          NaN
# std            0.0                       NaN          NaN
# min         2010.0                       NaN          NaN
# 25%         2010.0                       NaN          NaN
# 50%         2010.0                       NaN          NaN
# 75%         2010.0                       NaN          NaN
# max         2010.0                       NaN          NaN
#
#        Represented Test Veh Model Test Vehicle ID  Test Veh Configuration #  \
# count                        3277            3277               3277.000000
# unique                        524             750                       NaN
# top                         Jetta    EDV 93LD-TAQ                       NaN
# freq                           62              30                       NaN
# mean                          NaN             NaN                  2.098871
# std                           NaN             NaN                  4.067725
# min                           NaN             NaN                  0.000000
# 25%                           NaN             NaN                  0.000000
# 50%                           NaN             NaN                  1.000000
# 75%                           NaN             NaN                  2.000000
# max                           NaN             NaN                 50.000000
#
#         Test Veh Displacement (L) Actual Tested Testgroup Vehicle Type  \
# count                 3277.000000                    3277         3277
# unique                        NaN                     398            3
# top                           NaN            AGMXT05.3373          Car
# freq                          NaN                      92         1808
# mean                     3.472831                     NaN          NaN
# std                      1.296540                     NaN          NaN
# min                      0.001000                     NaN          NaN
# 25%                      2.400000                     NaN          NaN
# 50%                      3.195000                     NaN          NaN
# 75%                      4.300000                     NaN          NaN
# max                      8.400000                     NaN          NaN
#
#         Rated Horsepower  # of Cylinders and Rotors Tested Transmission Type  \
# count        3277.000000                2430.000000                     3277
# unique               NaN                        NaN                        6
# top                  NaN                        NaN                Automatic
# freq                 NaN                        NaN                     1738
# mean          263.988404                   5.951852                      NaN
# std           107.505203                   1.733995                      NaN
# min            35.000000                   3.000000                      NaN
# 25%           175.000000                   4.000000                      NaN
# 50%           255.000000                   6.000000                      NaN
# 75%           315.000000                   8.000000                      NaN
# max          1001.000000                  12.000000                      NaN
#
#        Drive System Description   # of Gears Test Fuel Type Description  \
# count                      3277  3277.000000                       3277
# unique                        5          NaN                         10
# top        2-Wheel Drive, Front          NaN       Tier 2 Cert Gasoline
# freq                       1429          NaN                       2674
# mean                        NaN     5.278303                        NaN
# std                         NaN     1.463453                        NaN
# min                         NaN     1.000000                        NaN
# 25%                         NaN     5.000000                        NaN
# 50%                         NaN     6.000000                        NaN
# 75%                         NaN     6.000000                        NaN
# max                         NaN     8.000000                        NaN
#
#          CO2 (g/mi)
# count   2988.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean     348.713576
# std      117.920807
# min      121.840334
# 25%      255.000000
# 50%      332.113787
# 75%      416.025000
# max     1012.000000

# %%
# Display summary statistics of string columns only by setting argument include=[object]
data.describe(include = [object])
# Out:
#        Vehicle Manufacturer Name Veh Mfr Code Represented Test Veh Model  \
# count                       3277         3277                       3277
# unique                        33           33                        524
# top                       Nissan          NSX                      Jetta
# freq                         485          485                         62
#
#        Test Vehicle ID Actual Tested Testgroup Vehicle Type  \
# count             3277                    3277         3277
# unique             750                     398            3
# top       EDV 93LD-TAQ            AGMXT05.3373          Car
# freq                30                      92         1808
#
#        Tested Transmission Type Drive System Description  \
# count                      3277                     3277
# unique                        6                        5
# top                   Automatic     2-Wheel Drive, Front
# freq                       1738                     1429
#
#        Test Fuel Type Description
# count                        3277
# unique                         10
# top          Tier 2 Cert Gasoline
# freq                         2674

# %% [markdown]
# # 3. Exploring particular column

# %%
# Display counts of unique values of the column 'Tested Transmission Type' using .value_counts() method
data['Tested Transmission Type'].value_counts()
# Out:
# Automatic                1738
# Manual                    796
# Semi-Automatic            474
# Continuously Variable     219
# Other                      26
# Automated Manual           24
# Name: Tested Transmission Type, dtype: int64

# %%
# Display relative frequencies of the unique values of the column 'Tested Transmission Type' by setting argument normalize = True
data['Tested Transmission Type'].value_counts(normalize = True)
# Out:
# Automatic                0.530363
# Manual                   0.242905
# Semi-Automatic           0.144644
# Continuously Variable    0.066829
# Other                    0.007934
# Automated Manual         0.007324
# Name: Tested Transmission Type, dtype: float64

# %% [markdown]
# # 4. Using boxplot

# %%
# Import seaborn as sns and matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# Set the size of the figure
plt.figure(figsize = (9,10))

# Create a boxplot to show the distribution of datapoints of the column 'Rated Horsepower'
sns.boxplot(data['Rated Horsepower'], orient = 'v', linewidth = 2, color ='skyblue');
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
# Set the size of the figure
plt.figure(figsize = (9,10))

# TASK 9 >>> Create a boxplot to show the distribution of datapoints of the column 'Test Veh Displacement (L)' that describes engine displacement
sns.boxplot(data['Test Veh Displacement (L)'], orient = 'v', linewidth = 2, color ='skyblue');
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# Material adapted for RBI internal purposes with full permissions from original authors. Source: https://github.com/zatkopatrik/authentic-data-science
